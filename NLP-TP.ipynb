# %% [markdown]
# 폴더 변경

# %%
import os
os.chdir("./drive/My Drive/course-NLP-TP")

# %% [markdown]
# 데이터셋

# %%
'''
os.chdir("./dataset/")
# !git clone https://github.com/e9t/nsmc.git
# Friend는 따로 다운 받음 -> http://doraemon.iis.sinica.edu.tw/emotionlines/download.html
os.chdir("..")
# !pwd # /content/drive/My Drive/course-NLP-TP/
'''
# Out:
# '\nos.chdir("./dataset/")\n!git clone https://github.com/e9t/nsmc.git\n# Friend는 따로 다운 받음 -> http://doraemon.iis.sinica.edu.tw/emotionlines/download.html\nos.chdir("..")\n!pwd # /content/drive/My Drive/course-NLP-TP/\n'

# %% [markdown]
# # KoBERT (한글, run with GPU) -> **acc = 0.89394**

# %% [markdown]
# **KoBERT nsmc** 코드 clone

# %%
# !git clone https://github.com/monologg/KoBERT-nsmc.git
os.chdir("KoBERT-nsmc/")
# Out:
# Cloning into 'KoBERT-nsmc'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 158 (delta 91), reused 116 (delta 53), pack-reused 0
# Receiving objects: 100% (158/158), 8.10 MiB | 10.87 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %% [markdown]
# Dependencies

# %%
# !pip install torch==1.4.0
# !pip install transformers==2.9.1

# %% [markdown]
# Training

# %%
# !python3 main.py --model_type kobert --do_train --do_eval
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Iteration:  28% 1306/4688 [16:36<31:30,  1.79it/s]
# Iteration:  28% 1307/4688 [16:36<31:17,  1.80it/s]
# Iteration:  28% 1308/4688 [16:37<31:10,  1.81it/s]
# Iteration:  28% 1309/4688 [16:37<31:13,  1.80it/s]
# Iteration:  28% 1310/4688 [16:38<31:14,  1.80it/s]
# Iteration:  28% 1311/4688 [16:38<31:18,  1.80it/s]
# Iteration:  28% 1312/4688 [16:39<31:23,  1.79it/s]
# Iteration:  28% 1313/4688 [16:39<31:19,  1.80it/s]
# Iteration:  28% 1314/4688 [16:40<31:21,  1.79it/s]
# Iteration:  28% 1315/4688 [16:41<31:20,  1.79it/s]
# Iteration:  28% 1316/4688 [16:41<31:25,  1.79it/s]
# Iteration:  28% 1317/4688 [16:42<31:16,  1.80it/s]
# Iteration:  28% 1318/4688 [16:42<31:16,  1.80it/s]
# Iteration:  28% 1319/4688 [16:43<31:14,  1.80it/s]
# Iteration:  28% 1320/4688 [16:43<31:16,  1.79it/s]
# Iteration:  28% 1321/4688 [16:44<31:10,  1.80it/s]
# Iteration:  28% 1322/4688 [16:44<31:09,  1.80it/s]
# Iteration:  28% 1323/4688 [16:45<31:03,  1.81it/s]
# ...

# %%
# !python3 predict.py
# Out:
# 2020-05-16 18:47:23.967434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 05/16/2020 18:47:26 - INFO - transformers.configuration_utils -   loading configuration file ./model/config.json
# 05/16/2020 18:47:26 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "nsmc",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": 0,
#     "1": 1
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "0": 0,
#     "1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "type_vocab_size": 2,
#   "vocab_size": 8002
# }
#
# ...

# %% [markdown]
# # HanBERT (한글, run with GPU) -> **acc = 0.90002**

# %% [markdown]
# 레포 클론

# %%
#!git clone https://github.com/monologg/HanBert-Transformers.git
#os.chdir("./HanBert-Transformers")
#!git clone https://github.com/monologg/HanBert-nsmc.git
os.chdir("./HanBert-nsmc")
# !ls
# Out:
# data		       LICENSE	    README.md		     trainer.py
# data_loader.py	       main.py	    requirements.txt	     utils.py
# HanBert-54kN-IP-torch  model	    res.gsheet
# HanBert-54kN-torch     predict.py   sample_pred_in.txt
# ko_data_out.txt        __pycache__  tokenization_hanbert.py

# %% [markdown]
# Install Dependencies

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 753.4MB 22kB/s
# ...
#      |████████████████████████████████| 552kB 49.5MB/s
# ...
#      |████████████████████████████████| 3.7MB 60.5MB/s
# ...
#      |████████████████████████████████| 1.1MB 54.4MB/s
# ...
#      |████████████████████████████████| 890kB 60.6MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=b0f4cceceb38ded1021c72704975cd0202c83f4e252306fee4c9a9705671b492
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ERROR: torchvision 0.6.0+cu101 has requirement torch==1.5.0, but you'll have torch 1.4.0 which is incompatible.
# ...
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
# ...

# %% [markdown]
# 실행을 위해 위 github의 instruction을 따라 모델을 다운로드 받은 후, 아래 커맨드를 실행

# %%
# !python3 main.py --model_type hanbert --model_name_or_path HanBert-54kN-torch --do_train --do_eval
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Evaluating:  13% 98/782 [00:09<01:04, 10.57it/s]
#
# Evaluating:  13% 100/782 [00:09<01:04, 10.55it/s]
#
# Evaluating:  13% 102/782 [00:09<01:04, 10.57it/s]
#
# Evaluating:  13% 104/782 [00:09<01:03, 10.60it/s]
#
# Evaluating:  14% 106/782 [00:10<01:03, 10.58it/s]
#
# Evaluating:  14% 108/782 [00:10<01:03, 10.54it/s]
#
# Evaluating:  14% 110/782 [00:10<01:03, 10.52it/s]
#
# Evaluating:  14% 112/782 [00:10<01:03, 10.54it/s]
#
# Evaluating:  15% 114/782 [00:10<01:03, 10.56it/s]
#
# Evaluating:  15% 116/782 [00:10<01:03, 10.55it/s]
#
# Evaluating:  15% 118/782 [00:11<01:02, 10.57it/s]
#
# Evaluating:  15% 120/782 [00:11<01:02, 10.57it/s]
#
# Evaluating:  16% 122/782 [00:11<01:02, 10.57it/s]
#
# Evaluating:  16% 124/782 [00:11<01:02, 10.60it/s]
#
# Evaluating:  16% 126/782 [00:11<01:01, 10.58it/s]
#
# Evaluating:  16% 128/782 [00:12<01:01, 10.57it/s]
#
# Evaluating:  17% 130/782 [00:12<01:01, 10.59it/s]
#
# ...

# %% [markdown]
# # KoELECTRA (한글, run with GPU) -> **acc = 0.90152**

# %% [markdown]
# 레포 클론

# %%
# !git clone https://github.com/monologg/KoELECTRA.git
os.chdir("./KoELECTRA/finetune")

# %% [markdown]
# Dependencies

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 753.4MB 21kB/s
# ...
#      |████████████████████████████████| 573kB 48.1MB/s
# ...
#      |████████████████████████████████| 1.1MB 41.6MB/s
# ...
#      |████████████████████████████████| 890kB 48.2MB/s
# ...
#      |████████████████████████████████| 3.7MB 54.4MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-0.0.12-cp36-none-any.whl size=7424 sha256=5a08bde5809749223fcb36f0ba7c636271bac501f094725ca12bfec62907ee80
#   Stored in directory: /root/.cache/pip/wheels/4f/32/0a/df3b340a82583566975377d65e724895b3fad101a3fb729f68
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=9d143e49b4bc66c960bd73f34eab12e1b10b3103e44880c473d54fb95e029768
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built seqeval sacremoses
# ERROR: torchvision 0.6.0+cu101 has requirement torch==1.5.0, but you'll have torch 1.4.0 which is incompatible.
# ...

# %% [markdown]
# 학습 + prediction.
# KoELECTRA는 KoBERT, HanBERT와 다르게 training code 내에서 저장되는 checkpoint가 생성될 때마다 해당 checkpoint로 kaggle data에 대한 prediction을 진행 후 결과 label을 저장하게 만들어 둠

# %%
# !python3 run_seq_cls.py --task nsmc --config_file koelectra-base.json
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# ...

# %% [markdown]
# # 한글 제출용

# %% [markdown]
# 경로

# %%
#os.chdir("HanBert-nsmc/")
os.chdir("./KoELECTRA/finetune")

# %% [markdown]
# prediction (KoELECTRA 제외 / ko_data.txt에 kaggle의 test data를 넣으면 ko_data_out.txt가 나오게 됨 (prediction 결과 label)

# %%
# !python3 predict.py --input_file '../test/ko_data.txt' --output_file './ko_data_out.txt'
# Out:
# python3: can't open file 'predict.py': [Errno 2] No such file or directory
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-f617c682cb64>", line 1, in <module>
#     get_ipython().system("python3 predict.py --input_file '../test/ko_data.txt' --output_file './ko_data_out.txt'")
#   File "/usr/local/lib/python3.6/dist-packages/google/colab/_shell.py", line 102, in system
#     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#   File "/usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py", line 438, in _system_compat
#     shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %% [markdown]
# prediction 결과를 제출용 csv 파일 형식에 맞추기. Id column의 header는 추가하는 법을 몰라서 아래 코드 실행 결과인 res.csv에서 직접 추가해서 제출함

# %%
import pandas as pd

#data = open("./ko_data_out.txt") # HanBERT
data = open("./res2020-06-22 08:03:39.txt")  # KoELECTRA
dataframe = pd.DataFrame(data, columns=["Predicted"], dtype='int32')
pd.to_numeric(dataframe['Predicted'])
dataframe.to_csv("res.csv", index=True)
